# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %%
clinic_locations = pd.read_csv('Chicago_Department_of_Public_Health_Clinic_Locations.csv')
CHI_2010_and_2000_pop= pd.read_csv('Chicago_2010_and_2000_Census_by_community_pop.csv')
gon_female = pd.read_csv('Public_Health_Statistics-_Gonorrhea_cases_for_females_aged_15_-_44_in_Chicago__by_year__2000_-__2014.csv',index_col=0)
chl_female = pd.read_csv('Public_Health_Statistics-_Chlamydia_cases_among_females_aged_15-44_in_Chicago__by_year__2000-2014..csv',index_col=0)
gon_male = pd.read_csv('Public_health_statistics-_Gonorrhea_cases_for_males_aged_15-44_in_Chicago__by_year__2000_-_2014.csv',index_col=0)
chl_male = pd.read_csv('Public_Health_Statistics_-_Chlamydia_cases_among_males_aged_15-44_in_Chicago__by_year__2000-2014.csv',index_col=0)

# %%
gon_female.fillna(value=0)
gon_female_clean= gon_female.dropna()
gon_female_clean
# Out:
#                                   year   2000   2001   2002   2003   2004  \
# community_area     community_area_name  Cases  Cases  Cases  Cases  Cases
# 1                          Rogers Park     84     88     85     70     45
# 2                           West Ridge     14     17     12     19     28
# 3                               Uptown     71     64     56     31     43
# 6                            Lake View     18     17     17     16     37
# 7                         Lincoln Park     25     22     16     16     25
# 8                      Near North Side    102    117    141    104     94
# 27                  East Garfield Park    141    136    135    118    131
# 14                         Albany Park      8      7     12     15     16
# 15                        Portage Park      5     13      5     13     14
# 16                         Irving Park     13     15     20      9     18
# 19                      Belmont Cragin     17     21     30     23     32
# ...

# %%
gon_female_clean.drop(['88'])
# Out:
#                                   year   2000   2001   2002   2003   2004  \
# community_area     community_area_name  Cases  Cases  Cases  Cases  Cases
# 1                          Rogers Park     84     88     85     70     45
# 2                           West Ridge     14     17     12     19     28
# 3                               Uptown     71     64     56     31     43
# 6                            Lake View     18     17     17     16     37
# 7                         Lincoln Park     25     22     16     16     25
# 8                      Near North Side    102    117    141    104     94
# 27                  East Garfield Park    141    136    135    118    131
# 14                         Albany Park      8      7     12     15     16
# 15                        Portage Park      5     13      5     13     14
# 16                         Irving Park     13     15     20      9     18
# 19                      Belmont Cragin     17     21     30     23     32
# ...

# %%
chl_female.fillna(value=0)
chl_female_clean= chl_female.dropna()

# %%
chl_female_clean.drop(['99', '88'])
# Out:
#                                   year   2000   2001   2002   2003   2004  \
# community_area     community_area_name  Cases  Cases  Cases  Cases  Cases
# 1                          Rogers Park    258    217    229    224    189
# 2                           West Ridge     69     66     71     67    100
# 3                               Uptown    169    157    133    127    128
# 4                       Lincoln Square     51     59     45     43     52
# 5                         North Center     26     35     28     30     41
# 6                            Lake View     71     69     88     67    107
# 7                         Lincoln Park     56     53     65     57     83
# 8                      Near North Side    171    214    207    227    239
# 10                        Norwood Park     12     10     21     11     15
# 11                      Jefferson Park      5      8     18     16     14
# 13                          North Park     11      7     13     15     14
# ...

# %%
gon_male.fillna(value=0)
gon_male_clean= gon_male.dropna()

# %%
gon_male_clean.drop(['99', '88'])
# Out:
#                                   year   2000   2001   2002   2003   2004  \
# community_area     community_area_name  Cases  Cases  Cases  Cases  Cases
# 1                          Rogers Park    115    112    125     83     64
# 2                           West Ridge     23     29     27     22     14
# 3                               Uptown    165    152    119     97    107
# 4                       Lincoln Square     17     18     11      6     11
# 6                            Lake View    127     88     85    122    106
# 7                         Lincoln Park     24     22     30     24     26
# 8                      Near North Side    101     78     82     84     67
# 14                         Albany Park     15     17     19     10      8
# 16                         Irving Park     11     19     16     10     12
# 19                      Belmont Cragin      9     25     33     23     20
# 21                            Avondale      6      9     15      6      7
# ...

# %%
chl_male.fillna(value=0)
chl_male_clean=chl_male.dropna()

# %%
chl_male_clean.drop(['99', '88'])
# Out:
#                                   year   2000   2001   2002   2003   2004  \
# community_area     community_area_name  Cases  Cases  Cases  Cases  Cases
# 1                          Rogers Park     89    108    136     84     92
# 2                           West Ridge     21     31     51     32     36
# 3                               Uptown     58     93    109     88     89
# 4                       Lincoln Square     13     11     21     24     24
# 5                         North Center     11     18     14     16     13
# 6                            Lake View     69     68     62     94    111
# 7                         Lincoln Park     17     19     26     30     33
# 8                      Near North Side     53     61    114     77     54
# 28                      Near West Side     81    122    166    133    105
# 14                         Albany Park     18     32     39     33     13
# 15                        Portage Park      9     10     22     18     16
# ...

# %%
CHI_2010_and_2000_pop
#Top 5 by population are 25-Austin, 6-Lakeview, 24-West Town, 8-Near North Side, 30-South Lawnside (all populations over 79,000)
#Bottom 5 by pop are 37-Fuller Park, 47-Burnside, 36-Oakland, 54-Riverdale, 50-Pullman
# Out:
#             Community Name  Total Population 2010  Total Polulation 2000
# 0              Rogers Park                  54991                  63484
# 1               West Ridge                  71942                  73199
# 2                   Uptown                  56362                  63551
# 3           Lincoln Square                  39493                  44574
# 4             North Center                  31867                  31895
# 5                Lake View                  94368                  94817
# 6             Lincoln Park                  64116                  64320
# 7          Near North Side                  80484                  72811
# 8              Edison Park                  11187                  11259
# 9             Norwood Park                  37023                  37669
# 10          Jefferson Park                  25448                  25859
# 11             Forest Glen                  18508                  18165
# ...
